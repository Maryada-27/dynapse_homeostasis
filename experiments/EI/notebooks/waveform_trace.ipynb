# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
# %config InlineBackend.figure_format='retina'

# %%
import pandas as pd
dfcsv = pd.read_csv('/media/mb/Data/Waveform_snapshots/Dynap_torch_trace_25ms.csv',header=None)

# %%
FS = 4
rec_time = np.arange(0,60*1000, 1/FS)
figB = plt.figure(figsize = (15,5))
plt.plot(rec_time[:-1],dfcsv[0].values)
plt.xlim(10550,11250)
plt.show()

# %%
FS = 4
rec_time = np.arange(0,60*1000, 1/FS)
figB = plt.figure(figsize = (15,5))
plt.plot(rec_time[:-1],dfcsv[0].values)
# plt.xlim(3800,4600)
plt.show()

# %%
len(rec_time)
# Out:
# 240000
